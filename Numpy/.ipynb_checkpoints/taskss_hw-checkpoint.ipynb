# %% [markdown]
# ## homework task -12 sep

# %%
# 1. create a array containing element 1 to 15
# 2. create a araay of mixed data types containing 4 elements and tell what datatype will change and why
# 3. on the above created array find the datatype of elements
# 4. create a array of size 7 and also print the size
# 5. create a array of 1st 5 even number and print size, datatype, total memory of array, shape of array,and which dimension is the array is and alsoo write one line definition what the attributes are doing

# %% [markdown]
# ## homework task -16 sep
